# %% [markdown]
# <a href="https://colab.research.google.com/github/claracavalcante/pycon-sweden-2020/blob/main/PyCon_Sweden_2020_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PyCon Sweden 2020 - How to make opportunities fall into your lap?

# %% [markdown]
# ## **Beautiful Soup**
#
# Beautiful Soup is a Python library for extracting data from HTML and XML files. It works as an interpreter (parser) in order to provide more intuitive ways to browse, search and modify the information contained in any markup document.
#
# In the first steps below, we will import the BeautifulSoup library and demonstrate some basic operations in an HTML example.

# %%
from bs4 import BeautifulSoup

# %%
html = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### Important methods

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find('a')
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.get_text()
# Out:
# "The Dormouse's story"

# %%
soup.select('body a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('p > #link1')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %%
soup.select('body > .title')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>]

# %% [markdown]
# ## **Remoteok.io**

# %% [markdown]
# [Link to Remoteok.io](https://remoteok.io/remote-dev-jobs)

# %% [markdown]
# Several libraries can be used to collect web pages. In this presentation we will use *urllib*.

# %%
from urllib.request import Request, urlopen

# %%
url = 'https://remoteok.io/remote-dev-jobs'
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})

web_byte = urlopen(req).read()
web_page = web_byte.decode('latin-1') #'utf-8'

web_page[:800]
# Out:
# '<!doctype html><notice cached="true" /><html class="tag catch-emails-enabled"><head><link rel="stylesheet" href="/assets/index.css?91603940353" /><title>Remote Software Developer Jobs</title><link rel=\'alternate\' type=\'application/rss+xml\' title=\'RSS\' href=\'/remote-dev-jobs.rss\'><link rel=\'alternate\' type=\'application/json\' title=\'JSON\' href=\'/remote-dev-jobs.json\'> <meta name="twitter:widgets:csp" content="on"><meta charset="UTF-8" /><meta http-equiv="Content-Language" content="en-us" /><link rel="search" type="application/opensearchdescription+xml" title="Remote OK" href="/opensearch.xml" /><meta name="google" value="notranslate" /><meta name="twitter:label1" value="Positions"><meta name="twitter:data1" value="Ruby On Rails Developer, Cloud Computing Architect and Senior NLP Software Eng'

# %% [markdown]
# We will use BeautifulSoup as a parser for the collected content. The BeautifulSoup object represents the parsed document as a whole.

# %%
soup = BeautifulSoup(web_page, 'html.parser')

section = soup.find("table")

print(section)
# Out:
# <table id="jobsboard"><thead><tr><th class="heading" colspan="999" style="position:relative;"><h1>Today's remote Software Developer jobs </h1><style>@media (max-width:1000px) {	.action-show-worldwide {	display:none;	}	}	.action-show-worldwide {	font-size:14px;	float:right;	position:absolute;	top:11px;	right:0;	}	.action-show-worldwide a {	color:#464646;	}	.action-show-worldwide:hover {	opacity:0.75;	}	.action-show-worldwide:active {	opacity:0.5;	}</style><div class="action-show-worldwide"><a href="/remote-dev-jobs?location=worldwide">â¬ï¸	Only show worldwide jobs</a></div></th></tr></thead><style>tr.rc-insert {	cursor:pointer;	}	tr.rc-insert:hover {	opacity:0.75;	}	tr.rc-insert:active {	opacity:0.55;	}	@media (max-width:600px) {	tr.rc-insert .text {	width:calc(100% - 75px) !important;	}	tr.rc-insert .source {	display:none !important;	}	}	@media (max-width:400px) {	tr.rc-insert .subtext {	display:none !important;	}	}</style><script type="c815a9dde83a9ee4030a05bf-text/javascript">$(function() {	$('.rc-insert').bind('click',function(e) {	window.location.href=$('.rc-insert a').eq(0).attr('href');	});	})</script><tr class="rc-insert"><td colspan="100" style="font-family:sans-serif;background-color: #351584;background-image: linear-gradient(232.9deg,#6b2294 12.36%,#2461b1);background-image:url('/assets/remote-com-bg.png?3');background-size:cover;padding:14px;"><div class="image" style="display:inline-block;vertical-align:middle;"><a href="/remote-com" rel="follow" style="text-decoration:none;border:none;"><div class="logo" style="background-image:url('/assets/remote-com-logo.png?3');background-color:transparent !important;border:none !important;width:55px;"></div></a></div><div class="text" style="margin-left:7px;padding:0.75em;padding-left:0;font-weight:normal;display:inline-block;vertical-align:middle;width:calc(100% - 150px - 100px);"><a href="/remote-com" rel="follow" style="font-size:1.1em;text-decoration:none;border:none;font-weight:bold;color:#fff;font-family:sans-serif;">Meet the new standard in <span style="color:#6fdee7">Global Payroll</span></a><br/><a class="subtext" href="/remote-com" rel="follow" style="font-size:1.1em;text-decoration:none;border:none;font-weight:normal;color:#fff;opacity:0.75;font-size:15px;">Global payroll, benefits, taxes, and compliance for your remote team.</a><div class="sponsored">Sponsored</div></div><div class="source" style="display:inline-block;width:10em;vertical-align:middle;text-align:center;font-weight:bold;"><a href="/remote-com" rel="follow"><div class="no-logo" style="background:none;border:2px solid;border-color:#6fdee7 !important;border-radius:50px;"><p style="opacity:1;color:#fff;font-family:sans-serif;margin:0;padding:14px;">Talk with us</p></div></a></div></td></tr><tr><td colspan="10" style="height:10px;padding:0;"></td></tr><tr "="" class="job job-100227 verified new == remoteok-original remoteok-featured " data-company="Clevertech" data-epoch="1605216463" data-href="/remote-jobs/100227-remote-angular-developer-clevertech" data-id="100227" data-search="Clevertech Angular Developer angular javascript java angularjs dev digital nomad angularjs" data-stack="" data-url="/remote-jobs/100227-remote-angular-developer-clevertech" id="job-100227" title=""><td class="image has-logo"><script type="application/ld+json">{"@context":"http://schema.org","@type":"JobPosting","datePosted":"2020-11-12T13:27:43-08:00","description":"**What is Required:**\n* Superior communication skills in English\n* 5+ years of software development experience\n* Observables experience preferred\n* Strong JavaScript coding experience (Angular 2+)\n* Recent production-level experience with Angular\n* Ability to effectively articulate technical challenges and solutions\n\n**How We Work**\nWhy do people join Clevertech? To make an impact. To grow themselves. To be surrounded by developers who they can learn from. We are truly excited to be creating waves in an industry under transformation.\n\nTrue innovation come ...

# %%
jobs = []

for tr in section.find_all('tr', 'job'):
  job = {}
  if tr.find('td', 'source').a:
    job['company'] = tr.h3.get_text()
    job['role'] = tr.h2.get_text()
    
    #if tr.find('td', 'company_and_position').find('div', 'location'): 
      #job['location'] = tr.div.get_text().encode('ascii', 'replace')
      

    job['tags'] = []
    get_tags = tr.find('td', 'tags')
    for tag in get_tags.find_all('div', 'tag'):
      job['tags'].append(tag.h3.get_text())

    job['link'] = 'https://remoteok.io' + tr.find('td', 'source').a['href']
    jobs.append(job)

jobs
# Out:
# [{'company': 'Clevertech',
#   'link': 'https://remoteok.io/l/100227',
#   'role': 'Angular Developer',
#   'tags': ['angular', 'javascript', 'java', 'angularjs']},
#  {'company': 'Octopods',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Senior Frontend Engineer',
#   'tags': ['dev', 'javascript', 'react', 'vuejs']},
#  {'company': 'IGBlade',
#   'link': 'https://remoteok.io/l/100211',
#   'role': 'Experienced Frontend Developer',
#   'tags': ['vue', 'bootstrap', 'frontend', 'graphql']},
#  {'company': 'Semaphore',
#   'link': 'https://remoteok.io/l/100209',
#   'role': 'Senior Software Engineer',
#   'tags': ['software engineering', 'paas', 'elixir', 'go']},
#  {'company': 'Forestreet',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Front End Developer',
#   'tags': ['react', 'javascript', 'typescript', 'rest apis']},
#  {'company': 'Alcumus',
#   'link': 'https://remoteok.io/l/100218',
#   'role': 'Software Developer',
#   'tags': ['dev']},
#  {'company': 'riskmethods',
#   'link': 'https://remoteok.io/l/100199',
#   'role': 'Senior Frontend Developer',
#   'tags': ['front end', 'dev', 'senior']},
#  {'company': 'Aula',
#   'link': 'https://remoteok.io/l/100181',
#   'role': 'Software Engineer 6 Month FTC',
#   'tags': ['javascript', 'react', 'react native', 'node']},
#  {'company': 'BuddyBoss',
#   'link': 'https://remoteok.io/l/100148',
#   'role': 'Senior PHP Developer',
#   'tags': ['developer', 'php', 'wordpress', 'react']},
#  {'company': 'KosmoTime',
#   'link': 'https://remoteok.io/l/100139',
#   'role': 'Front End Developer',
#   'tags': ['react', 'javascript', 'front end', 'dev']},
#  {'company': 'Visuary',
#   'link': 'https://remoteok.io/l/100119',
#   'role': 'Software Engineer',
#   'tags': ['fullstack', 'machine learning', 'dev', 'engineer']},
#  {'company': 'Visuary',
#   'link': 'https://remoteok.io/l/100117',
#   'role': 'Webgl Frontend Developer',
#   'tags': ['fullstack', '3d', 'vfx', 'front end']},
#  {'company': 'GooseChase',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Senior Full Stack Engineer',
#   'tags': ['dev', 'react', 'django', 'redux']},
#  {'company': 'MeetEdgar',
#   'link': 'https://remoteok.io/l/99495',
#   'role': 'P T Full Stack Developer',
#   'tags': ['react', 'rails', 'redux', 'postgres']},
#  {'company': 'Scanifly',
#   'link': 'https://remoteok.io/l/100193',
#   'role': 'Front End Developer',
#   'tags': ['front end', 'dev']},
#  {'company': 'ResoluteAI',
#   'link': 'https://remoteok.io/l/100189',
#   'role': 'Full Stack Software Engineer',
#   'tags': ['full stack', 'dev', 'engineer']},
#  {'company': 'R2',
#   'link': 'https://remoteok.io/l/100177',
#   'role': 'Senior Software Engineer',
#   'tags': ['dev', 'senior', 'engineer']},
#  {'company': 'intan media services',
#   'link': 'https://remoteok.io/l/100165',
#   'role': 'Software Engineer Full Work Possible',
#   'tags': ['dev', 'engineer']},
#  {'company': 'Scoocs OÃ',
#   'link': 'https://remoteok.io/l/100179',
#   'role': 'Full Stack Developer',
#   'tags': ['full stack', 'dev']},
#  {'company': 'Biomage',
#   'link': 'https://remoteok.io/l/100163',
#   'role': 'Full Stack Software Engineer',
#   'tags': ['full stack', 'dev', 'engineer']},
#  {'company': 'Joyride',
#   'link': 'https://remoteok.io/l/100155',
#   'role': 'Senior PHP Software Engineer',
#   'tags': ['dev', 'php', 'senior', 'engineer']},
#  {'company': 'BREDEX',
#   'link': 'https://remoteok.io/l/100159',
#   'role': 'Frontend Developer',
#   'tags': ['front end', 'dev']},
#  {'company': 'Level',
#   'link': 'https://remoteok.io/l/100142',
#   'role': 'Senior Software Engineer',
#   'tags': ['golang', 'dev', 'senior', 'engineer']},
#  {'company': 'Kaleido Health Solutions',
#   'link': 'https://remoteok.io/l/100132',
#   'role': 'Full Stack Developer',
#   'tags': ['full stack', 'dev']},
#  {'company': 'GoStudent',
#   'link': 'https://remoteok.io/l/100125',
#   'role': 'Senior Front End Developer',
#   'tags': ['front end', 'dev', 'senior']},
#  {'company': 'GSR',
#   'link': 'https://remoteok.io/l/100115',
#   'role': 'Java Developer Software Engineer',
#   'tags': ['dev', 'java', 'engineer']},
#  {'company': 'Argyle',
#   'link': 'https://remoteok.io/l/100105',
#   'role': 'Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'ECI Software Solutions',
#   'link': 'https://remoteok.io/l/100098',
#   'role': 'Senior Software Developer',
#   'tags': ['dev', 'senior']},
#  {'company': 'Admiral Insurance',
#   'link': 'https://remoteok.io/l/100094',
#   'role': 'Front End Developer',
#   'tags': ['front end', 'dev']},
#  {'company': 'Trainual',
#   'link': 'https://remoteok.io/l/100055',
#   'role': 'Senior Software Engineer',
#   'tags': ['ruby', 'rails', 'react', 'senior']},
#  {'company': 'Atlas Computer Systems',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Digital Marketing Manager',
#   'tags': ['software', 'financial services', 'fintech', 'technology']},
#  {'company': 'Earning Together',
#   'link': 'https://remoteok.io/l/100005',
#   'role': 'Full Stack Developer',
#   'tags': ['python', 'django', 'fintech', 'finance']},
#  {'company': 'Intent Technologies',
#   'link': 'https://remoteok.io/l/100003',
#   'role': 'Python Engineer',
#   'tags': ['python', 'backend', 'serverless', 'aws']},
#  {'company': 'Yellowdig',
#   'link': 'https://remoteok.io/l/99992',
#   'role': 'Software Engineer Backend',
#   'tags': ['javascript', 'clojure', 'datomic', 'docker']},
#  {'company': 'GlassDollar',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Full Stack Developer',
#   'tags': ['node', 'react', 'postgresql', 'aws']},
#  {'company': 'ThymeBase',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Senior Ruby on Rails Developer',
#   'tags': ['ruby', 'ruby on rails', 'saas', 'dev']},
#  {'company': 'Iterative',
#   'link': 'https://remoteok.io/l/99931',
#   'role': 'Technical Community Manager',
#   'tags': ['git', 'data science', 'machine learning', 'developer relations']},
#  {'company': 'Nomad Health',
#   'link': 'https://remoteok.io/l/99923',
#   'role': 'Frontend Engineer',
#   'tags': ['software engineer', 'react', 'nyc', 'javascript']},
#  {'company': 'Athenian',
#   'link': 'https://remoteok.io/l/99902',
#   'role': 'Senior Software Engineer Frontend',
#   'tags': ['javascript', 'reactjs', 'senior', 'd3js']},
#  {'company': 'komoot',
#   'link': 'https://remoteok.io/l/99900',
#   'role': 'Senior Web Developer',
#   'tags': ['javascript', 'reactjs', 'node', 'senior']},
#  {'company': 'Toptal',
#   'link': 'https://remoteok.io/l/99898',
#   'role': 'Senior Developer',
#   'tags': ['front end', 'back end', 'app', 'devops']},
#  {'company': 'Clarity Movement Co.',
#   'link': 'https://remoteok.io/l/99896',
#   'role': 'Senior Backend Developer',
#   'tags': ['python',
#    'mongodb',
#    'aws ec2 lambda api gatewayecs',
#    'amplify django']},
#  {'company': 'district0x',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Clojurescript Developer',
#   'tags': ['clojure', 'clojurescript', 'ethereum', 'solidity']},
#  {'company': 'Aggregage',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Senior Full Stack Developer',
#   'tags': ['java', 'html', 'css', 'javascript']},
#  {'company': 'Firstly',
#   'link': 'https://remoteok.io/l/99847',
#   'role': 'Salesforce Developer Admin',
#   'tags': ['salesforce', 'force com', 'dev', 'admin']},
#  {'company': 'vigie.co',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Senior Software Engineer',
#   'tags': ['golang', 'scraping', 'postgres', 'dev']},
#  {'company': 'Kontist',
#   'link': 'https://remoteok.io/l/99810',
#   'role': 'Senior Javascript Developer',
#   'tags': ['react', 'nodejs', 'typescript', 'react native']},
#  {'company': 'komoot',
#   'link': 'https://remoteok.io/l/99806',
#   'role': 'Reactjs Developer',
#   'tags': ['reactjs', 'node', 'javascript', 'react']},
#  {'company': 'komoot',
#   'link': 'https://remoteok.io/l/99798',
#   'role': 'Backend Developer Data Scientist',
#   'tags': ['backend', 'kotlin', 'java', 'scala']},
#  {'company': 'komoot',
#   'link': 'https://remoteok.io/l/99796',
#   'role': 'Senior Backend Developer',
#   'tags': ['backend', 'java', 'kotlin', 'scala']},
#  {'company': 'PolySwarm',
#   'link': 'https://remoteok.io/l/99794',
#   'role': 'Senior Front End Developer',
#   'tags': ['docker', 'react', 'javascript', 'html']},
#  {'company': 'JetBridge',
#   'link': 'https://remoteok.io/l/99792',
#   'role': 'Senior Software Engineer',
#   'tags': ['backend', 'python django', 'java', 'postgres']},
#  {'company': 'Learning Tapestry',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Software Engineer',
#   'tags': ['node', 'react', 'javascript', 'node dev']},
#  {'company': 'Bonfire.com',
#   'link': 'https://remoteok.io/l/99768',
#   'role': 'Director of Engineering',
#   'tags': ['director', 'software', 'engineering', 'manager']},
#  {'company': 'Funnelytics',
#   'link': 'https://remoteok.io/l/99766',
#   'role': 'Software Development Lead',
#   'tags': ['node', 'redshift', 'backend', 'postgres']},
#  {'company': 'Very LLC',
#   'link': 'https://remoteok.io/l/99730',
#   'role': 'Senior Software Engineer React React',
#   'tags': ['react', 'react native', 'javascript', 'python']},
#  {'company': 'More Digital Studios',
#   'link': 'https://remoteok.io/cdn-cgi/l/email-protection#...',
#   'role': 'Senior Frontend Developer',
#   'tags': ['senior', 'react', 'javascript', 'front end']},
#  {'company': 'Love, Bonito',
#   'link': 'https://remoteok.io/l/99696',
#   'role': 'Senior Vue JS Frontend Developer',
#   'tags': ['vue', 'frontend', 'retail', 'architecture']},
#  {'company': 'Visuary',
#   'link': 'https://remoteok.io/l/99688',
#   'role': 'Webgl Frontend Developer',
#   'tags': ['javascript', 'full stack', 'math', 'front end']},
#  {'company': 'Fiveable - Social Learning for High School Students',
#   'link': 'https://remoteok.io/l/99646',
#   'role': 'Senior Software Engineer',
#   'tags': ['react', 'full stack', 'edtech', 'javascript']},
#  {'company': 'Alchemy + Aim',
#   'link': 'https://remoteok.io/l/99622',
#   'role': 'Back End Wordpress Developer',
#   'tags': ['php', 'javascript', 'wordpress', 'backend']},
#  {'company': 'InReach Ventures',
#   'link': 'https://remoteok.io/l/99530',
#   'role': 'Back End Developer',
#   'tags': ['java', 'python', 'aws', 'docker']},
#  {'company': 'Givecloud',
#   'link': 'https://remoteok.io/l/99508',
#   'role': 'Senior Frontend Developer React',
#   'tags': ['react', 'javascript', 'front end', 'dev']},
#  {'company': 'Aha!',
#   'link': 'https://remoteok.io/l/99284',
#   'role': 'Sr Security Engineer â\x80\x94 Ruby on Rails',
#   'tags': ['security', 'ruby on rails', 'code review', 'infosec']},
#  {'company': 'Netdata Inc',
#   'link': 'https://remoteok.io/l/99258',
#   'role': 'Senior Software Engineer',
#   'tags': ['linux systems', 'problem solving', 'python', 'ruby']},
#  {'company': 'Netdata Inc',
#   'link': 'https://remoteok.io/l/99256',
#   'role': 'Senior Software Engineer',
#   'tags': ['go', 'cloud native', 'microservices architectures', 'html5']},
#  {'company': 'Netdata Inc',
#   'link': 'https://remoteok.io/l/99254',
#   'role': 'Senior Software Engineer Test',
#   'tags': ['set',
#    'software quality assurance',
#    'manual testing',
#    'ci cd pipelines']},
#  {'company': 'Netdata Inc',
#   'link': 'https://remoteok.io/l/99252',
#   'role': 'Senior Frontend Developer',
#   'tags': ['javascript', 'typescript', 'react', 'css']},
#  {'company': 'Iterative',
#   'link': 'https://remoteok.io/l/99244',
#   'role': 'Sr Software Engineer ML Open Source',
#   'tags': ['open source', 'machine learning', 'dvc', 'python']},
#  {'company': 'GCM Grosvenor',
#   'link': 'https://remoteok.io/l/100084',
#   'role': '.NET Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'SkuNexus',
#   'link': 'https://remoteok.io/l/100081',
#   'role': 'Senior Frontend Software Engineer',
#   'tags': ['front end', 'dev', 'senior', 'engineer']},
#  {'company': 'Expel',
#   'link': 'https://remoteok.io/l/100073',
#   'role': 'Software Engineer',
#   'tags': ['golang', 'dev', 'engineer']},
#  {'company': 'Bellish',
#   'link': 'https://remoteok.io/l/100075',
#   'role': 'Senior Mobile Developer We Are Common',
#   'tags': ['dev', 'mobile', 'senior']},
#  {'company': 'Insider',
#   'link': 'https://remoteok.io/l/100052',
#   'role': 'Senior Front End Developer',
#   'tags': ['front end', 'dev', 'senior']},
#  {'company': 'Reply',
#   'link': 'https://remoteok.io/l/100049',
#   'role': 'Symfony Developer',
#   'tags': ['dev']},
#  {'company': 'Pomerium',
#   'link': 'https://remoteok.io/l/100018',
#   'role': 'Senior Software Engineer',
#   'tags': ['golang', 'dev', 'senior', 'engineer']},
#  {'company': 'ALM Works',
#   'link': 'https://remoteok.io/l/100020',
#   'role': 'Senior Full Stack Developer',
#   'tags': ['full stack', 'dev', 'senior']},
#  {'company': 'PORTABLE MULTIMEDIA LIMITED',
#   'link': 'https://remoteok.io/l/100009',
#   'role': 'Backend .net Developer',
#   'tags': ['dev', 'backend']},
#  {'company': 'IDT Finland',
#   'link': 'https://remoteok.io/l/100007',
#   'role': 'Senior Android Developer',
#   'tags': ['dev', 'senior', 'android']},
#  {'company': 'Verimi',
#   'link': 'https://remoteok.io/l/100001',
#   'role': 'Fullstack Developer',
#   'tags': ['dev']},
#  {'company': '33reasons',
#   'link': 'https://remoteok.io/l/99999',
#   'role': 'Senior Full Stack Developer',
#   'tags': ['full stack', 'dev', 'senior']},
#  {'company': 'Metro Bank',
#   'link': 'https://remoteok.io/l/99990',
#   'role': 'Senior Java Developer',
#   'tags': ['dev', 'java', 'senior']},
#  {'company': 'DigitalOcean',
#   'link': 'https://remoteok.io/l/99983',
#   'role': 'Senior Software Engineer Performance Engineering',
#   'tags': ['golang', 'dev', 'senior', 'engineer']},
#  {'company': 'Dentally',
#   'link': 'https://remoteok.io/l/99981',
#   'role': 'Senior Software Engineer Full Stack',
#   'tags': ['full stack', 'dev', 'senior', 'engineer']},
#  {'company': 'Docker',
#   'link': 'https://remoteok.io/l/99979',
#   'role': 'Principal Software Engineer Backend',
#   'tags': ['golang', 'dev', 'engineer', 'backend']},
#  {'company': 'Niche',
#   'link': 'https://remoteok.io/l/99969',
#   'role': 'Software Engineer Back End',
#   'tags': ['golang', 'backend', 'dev', 'engineer']},
#  {'company': 'EstateSales.NET',
#   'link': 'https://remoteok.io/l/99967',
#   'role': 'Senior Angular Developer',
#   'tags': ['dev', 'javascript', 'angularjs', 'senior']},
#  {'company': 'The Jellyvision Lab',
#   'link': 'https://remoteok.io/l/99964',
#   'role': 'Software Engineering Manager',
#   'tags': ['dev', 'exec', 'engineer']},
#  {'company': 'MessageBird',
#   'link': 'https://remoteok.io/l/99962',
#   'role': 'Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'Wizenoze',
#   'link': 'https://remoteok.io/l/99956',
#   'role': 'Senior Frontend Developer',
#   'tags': ['front end', 'dev', 'senior']},
#  {'company': 'Mako Medical',
#   'link': 'https://remoteok.io/l/99941',
#   'role': 'Python Developer',
#   'tags': ['python', 'dev']},
#  {'company': 'Bimble Solar',
#   'link': 'https://remoteok.io/l/99933',
#   'role': 'PHP Opencart Web Developer',
#   'tags': ['dev', 'web dev', 'php', 'php']},
#  {'company': 'Cohesic',
#   'link': 'https://remoteok.io/l/99929',
#   'role': 'Full Stack Software Developer Interested Healthcare',
#   'tags': ['full stack', 'dev']},
#  {'company': 'Frequence',
#   'link': 'https://remoteok.io/l/99911',
#   'role': 'Front End Software Engineer',
#   'tags': ['front end', 'dev', 'engineer']},
#  {'company': 'Atomic Robot',
#   'link': 'https://remoteok.io/l/99907',
#   'role': 'Senior Android Developer',
#   'tags': ['dev', 'senior', 'android']},
#  {'company': 'an Exciting Sports AI Startup',
#   'link': 'https://remoteok.io/l/99892',
#   'role': 'IOS Developer Sparrow',
#   'tags': ['ios', 'dev', 'ios']},
#  {'company': 'KeldairHR',
#   'link': 'https://remoteok.io/l/99894',
#   'role': 'Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'BRG - The GAT Team',
#   'link': 'https://remoteok.io/l/99882',
#   'role': 'Frontend Vuejs Software Engineer',
#   'tags': ['vue', 'front end', 'dev', 'javascript']},
#  {'company': 'Open Door Logistics',
#   'link': 'https://remoteok.io/l/99880',
#   'role': 'Algorithmic Software Developer',
#   'tags': ['dev']},
#  {'company': 'Ridgeline International',
#   'link': 'https://remoteok.io/l/99869',
#   'role': 'Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'Bliss Applications',
#   'link': 'https://remoteok.io/l/99863',
#   'role': 'Front End Developer',
#   'tags': ['front end', 'dev']},
#  {'company': 'Comscore',
#   'link': 'https://remoteok.io/l/99859',
#   'role': 'Software Engineer II',
#   'tags': ['dev', 'engineer']},
#  {'company': 'Pie Insurance Holdings',
#   'link': 'https://remoteok.io/l/99853',
#   'role': 'Senior Backend Software Engineer',
#   'tags': ['dev', 'senior', 'engineer', 'backend']},
#  {'company': 'Analyst1',
#   'link': 'https://remoteok.io/l/99851',
#   'role': 'Senior Java Web Developer Excited Work On Cyber Intelligence',
#   'tags': ['dev', 'web dev', 'java', 'senior']},
#  {'company': 'CoreCare',
#   'link': 'https://remoteok.io/l/99840',
#   'role': 'Frontend Developer',
#   'tags': ['front end', 'dev']},
#  {'company': 'Pixelogic Media',
#   'link': 'https://remoteok.io/l/99838',
#   'role': 'Senior Software Development Engineer',
#   'tags': ['dev', 'senior', 'engineer']},
#  {'company': 'Trimdata Corp',
#   'link': 'https://remoteok.io/l/99834',
#   'role': 'Senior Engineer Developer Guide Fa~link Cloud',
#   'tags': ['dev', 'cloud', 'senior', 'engineer']},
#  {'company': 'Care.Com',
#   'link': 'https://remoteok.io/l/99828',
#   'role': 'Senior Software Engineer',
#   'tags': ['dev', 'senior', 'engineer']},
#  {'company': 'Inari Agriculture',
#   'link': 'https://remoteok.io/l/99826',
#   'role': 'Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'Leaf Logistics',
#   'link': 'https://remoteok.io/l/99823',
#   'role': 'React Frontend Developer',
#   'tags': ['react', 'front end', 'dev', 'javascript']},
#  {'company': 'FirstDown PlayBook',
#   'link': 'https://remoteok.io/l/99822',
#   'role': 'Lead Software Engineer',
#   'tags': ['dev', 'exec', 'engineer']},
#  {'company': 'Data Research Group',
#   'link': 'https://remoteok.io/l/99819',
#   'role': 'Mid Level TSQL Programmer',
#   'tags': ['dev']},
#  {'company': 'Inspired Thinking Group',
#   'link': 'https://remoteok.io/l/99813',
#   'role': 'Senior Front End Developer',
#   'tags': ['front end', 'dev', 'senior']},
#  {'company': 'LABSTER AG',
#   'link': 'https://remoteok.io/l/99812',
#   'role': 'Lead Software Engineer',
#   'tags': ['dev', 'exec', 'engineer']},
#  {'company': 'Tech9',
#   'link': 'https://remoteok.io/l/99802',
#   'role': 'Senior Principal React Go Node.js Software Engineer',
#   'tags': ['react', 'dev', 'javascript', 'node js']},
#  {'company': 'ValueWorks',
#   'link': 'https://remoteok.io/l/99781',
#   'role': 'Software Developer',
#   'tags': ['dev']},
#  {'company': 'Lootie',
#   'link': 'https://remoteok.io/l/99776',
#   'role': 'Senior Angular Developer With Igaming Experience',
#   'tags': ['dev', 'javascript', 'angularjs', 'senior']},
#  {'company': 'Sourcetable',
#   'link': 'https://remoteok.io/l/99770',
#   'role': 'Lead Backend Developer Data Engineer',
#   'tags': ['dev', 'exec', 'engineer', 'backend']},
#  {'company': 'Wishpond Technologies',
#   'link': 'https://remoteok.io/l/99762',
#   'role': 'Senior Ruby On Rail Web Developer',
#   'tags': ['dev', 'web dev', 'ruby', 'senior']},
#  {'company': 'Luxor',
#   'link': 'https://remoteok.io/l/99760',
#   'role': 'Software Engineer',
#   'tags': ['golang', 'dev', 'engineer']},
#  {'company': 'QONTO',
#   'link': 'https://remoteok.io/l/99757',
#   'role': 'Backend Software Engineer',
#   'tags': ['golang', 'dev', 'engineer', 'backend']},
#  {'company': 'Perimeter Software Solutions',
#   'link': 'https://remoteok.io/l/99758',
#   'role': 'Senior .net Full Stack Developer',
#   'tags': ['full stack', 'dev', 'senior']},
#  {'company': 'Heart Health Intelligence',
#   'link': 'https://remoteok.io/l/99755',
#   'role': 'Senior Software Engineer',
#   'tags': ['dev', 'senior', 'engineer']},
#  {'company': 'uShip',
#   'link': 'https://remoteok.io/l/99753',
#   'role': 'Senior Software Engineer',
#   'tags': ['dev', 'senior', 'engineer']},
#  {'company': 'Werum IT Solutions - yght Data Science',
#   'link': 'https://remoteok.io/l/99747',
#   'role': 'Software Engineer Developer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'Blockaviation',
#   'link': 'https://remoteok.io/l/99745',
#   'role': 'Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'Koi Consulting',
#   'link': 'https://remoteok.io/l/99734',
#   'role': 'Senior Go Stack Developer',
#   'tags': ['golang', 'dev', 'senior']},
#  {'company': 'SingleOps',
#   'link': 'https://remoteok.io/l/99724',
#   'role': 'Senior Software Engineer',
#   'tags': ['dev', 'senior', 'engineer']},
#  {'company': 'Airhouse',
#   'link': 'https://remoteok.io/l/99739',
#   'role': 'Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'FluentStream',
#   'link': 'https://remoteok.io/l/99717',
#   'role': 'Senior Software Developer',
#   'tags': ['dev', 'senior']},
#  {'company': 'DVSport',
#   'link': 'https://remoteok.io/l/99713',
#   'role': 'Senior Web Developer',
#   'tags': ['dev', 'web dev', 'senior']},
#  {'company': 'The Next Chapter',
#   'link': 'https://remoteok.io/l/99705',
#   'role': 'Intermediate Software Developer',
#   'tags': ['dev']},
#  {'company': 'ElevenYellow Pte',
#   'link': 'https://remoteok.io/l/99710',
#   'role': 'Junior Full Stack Developer',
#   'tags': ['meteor js', 'javascript', 'full stack', 'dev']},
#  {'company': 'Construo AG',
#   'link': 'https://remoteok.io/l/99694',
#   'role': 'Full Stack Developer With PHP Focus',
#   'tags': ['full stack', 'dev', 'php', 'php']},
#  {'company': 'OnePak',
#   'link': 'https://remoteok.io/l/99686',
#   'role': 'Expert Full Stack Developer',
#   'tags': ['full stack', 'dev']},
#  {'company': 'Agrian',
#   'link': 'https://remoteok.io/l/99681',
#   'role': 'Software Engineer',
#   'tags': ['dev', 'engineer']},
#  {'company': 'Kenoby',
#   'link': 'https://remoteok.io/l/99679',
#   'role': 'Pessoa Engenheira De Software SÃªnior',
#   'tags': ['dev', 'senior']},
#  {'company': 'CMAS Systems',
#   'link': 'https://remoteok.io/l/99677',
#   'role': 'Mulesoft Developer',
#   'tags': ['dev']},
#  {'company': 'CMAS Systems',
#   'link': 'https://remoteok.io/l/99676',
#   'role': 'Python Developer',
#   'tags': ['python', 'dev']},
#  {'company': 'n3o',
#   'link': 'https://remoteok.io/l/99669',
#   'role': '.NET Umbraco Developer',
#   'tags': ['dev']},
#  {'company': 'Pliancy',
#   'link': 'https://remoteok.io/l/99655',
#   'role': 'Senior Full Stack Developer',
#   'tags': ['full stack', 'dev', 'senior']},
#  {'company': 'West Arete',
#   'link': 'https://remoteok.io/l/99650',
#   'role': 'Senior Mobile Developer',
#   'tags': ['dev', 'mobile', 'senior']},
#  {'company': 'Prodsmart',
#   'link': 'https://remoteok.io/l/99644',
#   'role': 'Junior Full Stack Developer',
#   'tags': ['full stack', 'dev', 'junior']},
#  {'company': 'springbig',
#   'link': 'https://remoteok.io/l/99632',
#   'role': 'Senior Ruby On Rails Developer',
#   'tags': ['dev', 'ruby', 'senior', 'ruby']},
#  {'company': 'pulseData',
#   'link': 'https://remoteok.io/l/99630',
#   'role': 'Senior Full Stack Software Engineer',
#   'tags': ['full stack', 'dev', 'senior', 'engineer']},
#  {'company': 'The BHW Group',
#   'link': 'https://remoteok.io/l/99628',
#   'role': 'Lead Full Stack Developer',
#   'tags': ['full stack', 'dev', 'exec']}]

# %%
import pandas as pd

jobs_pd = pd.DataFrame(jobs)

jobs_pd.head()
# Out:
#       company  ...                                               link
# 0  Clevertech  ...                       https://remoteok.io/l/100227
# 1    Octopods  ...  https://remoteok.io/cdn-cgi/l/email-protection...
# 2     IGBlade  ...                       https://remoteok.io/l/100211
# 3   Semaphore  ...                       https://remoteok.io/l/100209
# 4  Forestreet  ...  https://remoteok.io/cdn-cgi/l/email-protection...
#
# [5 rows x 4 columns]

# %% [markdown]
# ### Filtering?

# %%
ideal_technology = 'python'

# %%
ideal_level = 'Senior'

# %%
import copy
filtered_jobs = []

for job in jobs:
  if ideal_technology in job['tags'] and ideal_level in job['role']:
    filtered_jobs.append(copy.deepcopy(job))

filtered_jobs
# Out:
# [{'company': 'Clarity Movement Co.',
#   'link': 'https://remoteok.io/l/99896',
#   'role': 'Senior Backend Developer',
#   'tags': ['python',
#    'mongodb',
#    'aws ec2 lambda api gatewayecs',
#    'amplify django']},
#  {'company': 'Very LLC',
#   'link': 'https://remoteok.io/l/99730',
#   'role': 'Senior Software Engineer React React',
#   'tags': ['react', 'react native', 'javascript', 'python']},
#  {'company': 'Netdata Inc',
#   'link': 'https://remoteok.io/l/99258',
#   'role': 'Senior Software Engineer',
#   'tags': ['linux systems', 'problem solving', 'python', 'ruby']}]

# %% [markdown]
# ## **We Work Remotely**

# %% [markdown]
# [Link to We Work Remotely](https://weworkremotely.com/)

# %%
from urllib.request import Request, urlopen

url = 'https://weworkremotely.com/categories/remote-programming-jobs#job-listings'
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})

web_byte = urlopen(req).read()
web_page = web_byte.decode('utf-8')


soup = BeautifulSoup(web_page, 'html.parser')

jobs = []

for li in section.find_all('li', 'feature'):
  job = {}
  job['company'] = li.find_all('span', 'company')[0].get_text()
  job['title'] = li.find('span', 'title').get_text()
  if li.find('span', 'region'):
    job['region'] = li.find('span', 'region').get_text()
  job['period'] = li.find_all('span', 'company')[1].get_text()
  jobs.append(job)

jobs
# Out:
# []

# %%
import pandas as pd

jobs_pd = pd.DataFrame(jobs)

jobs_pd.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
